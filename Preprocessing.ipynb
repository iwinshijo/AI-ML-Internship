# %% [markdown]
# <a href="https://colab.research.google.com/github/iwinshijo/AI-ML-Internship/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/preprocessing_practice_dataset.csv")
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 0          52350.0                   5     Calicut        No
# ...

# %%
df['Age_mean_imputed']=df['Age'].fillna(df['Age'].mean())
df['Age_median_imputed']=df['Age'].fillna(df['Age'].median())
df['Age_mode_imputed']=df['Age'].fillna(df['Age'].mode()[0])
df[['Age_mean_imputed','Age_median_imputed']]
# Out:
#     Age_mean_imputed  Age_median_imputed
# 0               59.0                59.0
# 1               49.0                49.0
# 2               35.0                35.0
# 3               28.0                28.0
# 4               41.0                41.0
# ..               ...                 ...
# 95              54.0                54.0
# 96              53.0                53.0
# 97              43.0                43.0
# 98              44.0                44.0
# 99              57.0                57.0
#
# [100 rows x 2 columns]

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience Years vs Monthly Salary')
plt.xlabel('Experience Years')
plt.ylabel('Monthly Salary')
plt.show()
# Out:
# /tmp/ipykernel_539/3253470997.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(20,6))
sns.boxplot(data=df,x='Age',y='Performance_Rating',palette='pastel')
plt.title('Age and Performance')
plt.show()
# Out:
# /tmp/ipykernel_539/1307351458.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Age',y='Performance_Rating',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Age',y='Experience_Years',palette='pastel')
plt.title('Boxplot of Experience and Age')
plt.show()
# Out:
# /tmp/ipykernel_539/3072157862.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Age',y='Experience_Years',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Performance_Rating',y='Experience_Years',palette='pastel')
plt.title('Boxplot of Experience and Performance')
plt.show()
# Out:
# /tmp/ipykernel_539/2513214072.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Performance_Rating',y='Experience_Years',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Performance_Rating',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Salary and Performance')
plt.show()
# Out:
# /tmp/ipykernel_539/3160997449.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Performance_Rating',y='Monthly_Salary',palette='pastel')
